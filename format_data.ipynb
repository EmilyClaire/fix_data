# %%
import standardize_data as std_data

new_dataframe = std_data.fix_data('emisvaluez.csv') 
new_dataframe
# Out:
#        Region       R     SNR   chi2    v(0)     sig  npop          mage  \
# CName
# A1668    core   2.500  29.727  0.496   88.03  334.50     4  1.240000e+10
# A1668  center   7.500  32.026  0.641  106.89  347.07     4  9.460000e+09
# A1668   outer  13.750  28.609  0.953  118.19  369.89     2  7.390000e+09
# A1668     icl  27.500  13.627  1.210  134.60  426.91     1  3.000000e+09
# A1795    core   1.250  37.717  0.872  -13.66  243.01     5  8.170000e+09
# A1795  center   5.000  29.747  0.952  -15.50  252.93     4  1.030000e+10
# A1795   outer  14.375  22.942  0.871   -9.43  246.36     4  9.630000e+09
# A1795     icl  33.125   6.943  0.904   -2.80  326.97     2  1.030000e+10
# A193     core   1.250  20.222  0.267  -19.84  491.56     4  1.300000e+10
# A193   center   5.000  21.828  0.303   22.04  444.30     2  1.300000e+10
# A193    outer  13.750  19.922  0.692 -119.50  415.31     5  1.250000e+10
# A193      icl  28.750  13.373  1.140  -19.89  333.92     3  9.930000e+09
# ...
